# %%
import os
path_to_csv = os.path.join("concat-dados", "data", "dataset-turmas")

# %%
import glob
import pandas as pd
# Out:
# /tmp/ipykernel_835/713037913.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   turmas_df=pd.read_csv("data/turmas.csv")

# %%
if not os.path.exists(path_to_csv):
    raise ValueError(f"O diretório {path_to_csv} não existe.")
csv_files = glob.glob(os.path.join(path_to_csv, "*.csv"))

# %%
df_list=[]
if not csv_files:
    print("Nenhum arquivo CSV encontrado no diretório.")
for file in csv_files:
    df_list.append(pd.read_csv(file, sep=";"))
concatenated_df = pd.concat(df_list, ignore_index=True)
output_path = os.path.join("data", "turmas.csv")
concatenated_df.to_csv(output_path, index=False)
print(f"Arquivos concatenados e salvos em: {output_path}")
# Out:
# Arquivos concatenados e salvos em: data/turmas.csv
