# %% [markdown]
# 1 - Professores substitutos vs Professores permanentes
#
# 2 - Comparar variáveis de forma imparcial para encontrar respostas
#
# 3 - O quanto um professor melhora ao longo dos anos
#
# 4 - Qual a relação das notas de um professor com o desempennho da turma (reprovação, trancamento, notas, etc)

# %% [markdown]
# ## Baixando bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Baixando bases de dados

# %%
df = pd.read_csv("../limpezaSegundafase/CSVs/Finais/avaliacoes_Docentes_Turmas.csv", sep = ";")

# %% [markdown]
# ## Visualização Inicial

# %%
df.head()
# Out:
#                                                 nome sexo   formacao  \
# 0  gAAAAABoK5E6j5TbqZPDJ5NYzMxdBZriI-CsNEuDKbVirf...    M   MESTRADO
# 1  gAAAAABoK5E6R1hu4dSPg8FkFOEIEmcEYHlYvmPJzZEPPd...    F  DOUTORADO
# 2  gAAAAABoK5E6eAVCeUnbWC3nbkQx-aLvuBnJzHRQosKbFN...    F  DOUTORADO
# 3  gAAAAABoK5E6qJDKzYFcqZH3pJgHamgSiwc4TQHNCtoo1d...    F  DOUTORADO
# 4  gAAAAABoK5E6U5XZ1G27srNXBhH4mD1rnNwCC3N_ABu4Tw...    F  DOUTORADO
#
#             vinculo                                         categoria  \
# 0  Ativo Permanente  PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO
# 1  Ativo Permanente  PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO
# 2  Ativo Permanente  PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO
# 3  Ativo Permanente  PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO
# 4  Ativo Permanente  PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO
#
#                                     classe_funcional  \
# 0  C                                             ...
# ...

# %%
display(df.info())
display(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126294 entries, 0 to 126293
# Data columns (total 28 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   nome                                  126294 non-null  object
#  1   sexo                                  126294 non-null  object
#  2   formacao                              126294 non-null  object
#  3   vinculo                               126294 non-null  object
#  4   categoria                             126294 non-null  object
#  5   classe_funcional                      126294 non-null  object
#  6   lotacao                               126294 non-null  object
#  7   id_turma                              126294 non-null  int64
#  8   ano                                   126294 non-null  int64
#  9   periodo                               126294 non-null  int64
# ...

# %%
df.describe()
# Out:
#            id_turma            ano        periodo  qtd_discentes  \
# count  1.262940e+05  126294.000000  126294.000000  126294.000000
# mean   5.012137e+07    2019.056083       1.512368      22.089347
# std    1.919767e+07       3.188825       0.499849      17.675052
# min    1.207257e+06    2013.000000       1.000000       0.000000
# 25%    5.759097e+07    2016.000000       1.000000       8.000000
# 50%    5.764478e+07    2019.000000       2.000000      17.000000
# 75%    5.769996e+07    2022.000000       2.000000      32.000000
# max    5.774096e+07    2024.000000       2.000000     306.000000
#
#        postura_profissional_media  postura_profissional_DP  \
# count               126294.000000            126294.000000
# mean                     9.398060                 0.984675
# std                      0.717236                 0.767934
# min                      0.000000                 0.000000
# 25%                      9.200000                 0.400000
# ...

# %% [markdown]
# ## Criando Colunas
# A partir da visualização inicial, percebemos que podemos criar colunas que representam os percentuais de alunos que foram aprovados, reprovados etc. em cada turma, a partir dos valores quantitativos que temos:

# %%
df['porcentagem_aprovado_total'] = ((df['qtd_aprovado_por_nota']+df['qtd_aprovado'])/df['qtd_discentes'])*100
df['porcentagem_aprovado'] = (df['qtd_aprovado']/df['qtd_discentes'])*100
df['porcentagem_reprovado_total'] = ((df['qtd_reprovado_por_média_e_por_faltas']+df['qtd_reprovado']+df['qtd_reprovado_por_faltas']+df['qtd_reprovado_por_nota_e_falta']+df['qtd_reprovado_por_nota'])/df['qtd_discentes'])*100
df['porcentagem_reprovado_por_faltas_total'] = ((df['qtd_reprovado_por_faltas']+df['qtd_reprovado_por_nota_e_falta']+df['qtd_reprovado_por_média_e_por_faltas'])/df['qtd_discentes'])*100
df['porcentagem_trancado'] = (df['qtd_trancado']/df['qtd_discentes'])*100
df['porcentagem_desistencia_total'] = ((df['qtd_desistencia']+df['qtd_trancado'])/df['qtd_discentes'])*100

# %% [markdown]
# Obs.: Acredito que "reprovado" é o aluno que reprovou direto, sem ir para a recuperação, mas não tenho certeza...
#
# Mas, olhando a tabela e o Sigaa, eu sei que não é equivalente à soma dos tipos de reprovado, como eu achei que poderia ser.

# %%
df.columns
# Out:
# Index(['nome', 'sexo', 'formacao', 'vinculo', 'categoria', 'classe_funcional',
#        'lotacao', 'id_turma', 'ano', 'periodo', 'qtd_discentes',
#        'postura_profissional_media', 'postura_profissional_DP',
#        'atuacao_profissional_media', 'atuacao_profissional_DP',
#        'autoavaliacao_aluno_media', 'autoavaliacao_aluno_DP', 'ano_admissao',
#        'media_final_geral', 'qtd_aprovado', 'qtd_desistencia',
#        'qtd_reprovado_por_média_e_por_faltas', 'qtd_trancado',
#        'qtd_aprovado_por_nota', 'qtd_reprovado', 'qtd_reprovado_por_faltas',
#        'qtd_reprovado_por_nota_e_falta', 'qtd_reprovado_por_nota',
#        'porcentagem_aprovado_total', 'porcentagem_aprovado',
#        'porcentagem_reprovado_total', 'porcentagem_reprovado_por_faltas_total',
#        'porcentagem_trancado', 'porcentagem_desistencia_total'],
#       dtype='object')

# %% [markdown]
# ## Análise geral

# %% [markdown]
# Primeiro, vamos ver a distribuição dos valores numéricos mais relevantes.

# %%
areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao']
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df[area], bins=30, kde=True, color='skyblue', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

# Remove o subplot extra (o 6º)
fig.delaxes(axes[-1])
fig.delaxes(axes[-2])

plt.tight_layout()
plt.show()

# %% [markdown]
# Agora, vamos analisar os valores qualitativos:

# %%
for column in df.iloc[:, 1:5]:
        display(df[column].value_counts())
# Out:
# sexo
# M    67289
# F    59005
# Name: count, dtype: int64
# formacao
# DOUTORADO         102655
# MESTRADO           17643
# ESPECIALIZAÇÃO      5877
# GRADUAÇÃO             51
# PÓS-DOUTORADO         45
# DESCONHECIDA          23
# Name: count, dtype: int64
# vinculo
# Ativo Permanente                           122964
# Professor Substituto                         1638
# Cedido                                        718
# Exercicio provisorio                          355
# Professor Temporario                          332
# Professor Visitante                           168
# Excedente de lotação                          108
# Colaborador PCCTAE e Magistério Federal        11
# Name: count, dtype: int64
# categoria
# PROFESSOR DO MAGISTERIO SUPERIOR                    121707
# PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO      2449
# PROFESSOR DO MAGISTERIO SUPERIOR - SUBSTITUTO         1616
# PROFESSOR DO MAGISTERIO SUPERIOR - TEMPORARIO          332
# ...

# %% [markdown]
# Como não sabemos as perguntas feitas nos formulários, vamos assumir que:
#
# Postura profissional é algo relativo ao profissionalismo. Já a atuação diz respeito às práticas de ensino.

# %% [markdown]
# ## Análises específicas

# %% [markdown]
# ### Professores não permanentes vs. Professores permanentes

# %% [markdown]
# Temos as seguintes possibilidades de vínculo para um professor:

# %%
df['vinculo'].value_counts()
# Out:
# vinculo
# Ativo Permanente                           122964
# Professor Substituto                         1638
# Cedido                                        718
# Exercicio provisorio                          355
# Professor Temporario                          332
# Professor Visitante                           168
# Excedente de lotação                          108
# Colaborador PCCTAE e Magistério Federal        11
# Name: count, dtype: int64

# %% [markdown]
# Pesquisando sobre cada uma das categorias de vínculo de professores do ensino superior, conseguimos as seguintes definições para cada:
#
# - **Ativo Permanente**: Professores efetivos aprovados em concurso público;
# - **Cedido**: Professores com vínculo com a instituição, mas cedidos para atuar em outro órgão ou entidade governamental;
# - **Professor Substituto**: Professor contratado temporariamente para substituir outro professor afastado;
# - **Exercício Provisório**: Quando o professor está temporariamente atuando em outra unidade ou campus diferente daquele onde está formalmente vinculado;
# - **Professor Visitante**: Professor ou pesquisador contratado por tempo determinado para atuar em atividades de ensino ou pesquisa.;
# - **Professor Temporário**: Semelhante ao "Professor Substituto", mas nem sempre envolve substituição direta;
# - **Excedente de Lotação**: Refere-se a professores cuja lotação excede o número de vagas autorizadas para determinado setor ou unidade;
#
# Portanto, temos que *necessariamente* satisfazem a condição de "Permanente":
#
# - Ativo Permanente, Cedido, Exercício Provisório
#
# E temos que os tipos de vínculo que caracterizam a condição de "Não permanente" são:
# - Professor Substituto, Professor Visitante, Professor Temporário
#
# Note que há incerteza sobre a categoria "Excedente de Lotação", pois não especifica se são professores permanentes ou não.
#
# Dadas essas informações, vamos separar Data Frames para cada tipo de professor:

# %%
tipos_permanentes = ['Ativo Permanente', "Cedido", "Exercicio provisorio"]
tipos_nao_permanentes = ['Professor Substituto', 'Professor Visitante', 'Professor Temporario']

df_professores_permanentes = df[df['vinculo'].isin(tipos_permanentes)]
df_professores_nao_permanentes= df[df['vinculo'].isin(tipos_nao_permanentes)]

# %% [markdown]
# #### Análise dos professores permanentes

# %% [markdown]
# Análise dos valores relacionados a notas:

# %%
notas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao', 'media_final_geral']
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
axes = axes.flatten()

for i, notas in enumerate(notas):
    sns.histplot(df_professores_permanentes[notas], bins=30, kde=True, color='skyblue', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {notas}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

# Remove o subplot extra (o 6º)
fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# Análise dos valores referentes a quantidades:

# %%
quantidades = ['qtd_aprovado', 'qtd_desistencia',
       'qtd_reprovado_por_média_e_por_faltas', 'qtd_trancado',
       'qtd_aprovado_por_nota', 'qtd_reprovado', 'qtd_reprovado_por_faltas',
       'qtd_reprovado_por_nota_e_falta', 'qtd_reprovado_por_nota']

print("=== Médias puras ===\n")

for column in quantidades:
    media = df_professores_permanentes[column].mean()
    print(f"{column:40s}: {media:.2f}")

print("\n==============================")

quantidades = ['porcentagem_aprovado_total', 'porcentagem_aprovado',
       'porcentagem_reprovado_total', 'porcentagem_reprovado_por_faltas_total',
       'porcentagem_trancado', 'porcentagem_desistencia_total']

print("=== Médias relativas ===\n")

for column in quantidades:
    media = df_professores_permanentes[column].mean()
    print(f"{column:40s}: {media:.2f}")

print("\n==============================")
# Out:
# === Médias puras ===
#
# qtd_aprovado                            : 15.09
# qtd_desistencia                         : 0.52
# qtd_reprovado_por_média_e_por_faltas    : 1.00
# qtd_trancado                            : 0.68
# qtd_aprovado_por_nota                   : 4.29
# qtd_reprovado                           : 1.56
# qtd_reprovado_por_faltas                : 0.02
# qtd_reprovado_por_nota_e_falta          : 0.01
# qtd_reprovado_por_nota                  : 0.04
#
# ...
# === Médias relativas ===
#
# porcentagem_aprovado_total              : 90.81
# porcentagem_aprovado                    : 72.87
# porcentagem_reprovado_total             : 9.09
# porcentagem_reprovado_por_faltas_total  : 3.80
# porcentagem_trancado                    : inf
# porcentagem_desistencia_total           : inf
#
# ...

# %% [markdown]
# Análise dos valores qualitativos:

# %%
classes = ['sexo', 'formacao', 'categoria', 'classe_funcional',
       'lotacao']

print("=== Ocorrências de cada valor ===\n")

for column in classes:
    numOcorrencias = df_professores_permanentes[column].value_counts()
    print(str(numOcorrencias) + "\n")

print("\n==============================")
# Out:
# === Ocorrências de cada valor ===
#
# sexo
# M    66166
# F    57871
# Name: count, dtype: int64
#
# formacao
# DOUTORADO         101604
# MESTRADO           16646
# ESPECIALIZAÇÃO      5700
# PÓS-DOUTORADO         45
# DESCONHECIDA          23
# GRADUAÇÃO             19
# Name: count, dtype: int64
#
# categoria
# PROFESSOR DO MAGISTERIO SUPERIOR                    121642
# PROFESSOR DE ENSINO BASICO TECNICO E TECNOLOGICO      2395
# Name: count, dtype: int64
#
# classe_funcional
# C                                                                                                       48419
# B                                                                                                       44614
# D                                                                                                       16467
# A                                                                                                       13900
# ...

# %% [markdown]
# #### Análise dos Professores não permanentes

# %%
areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao', 'media_final_geral']
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df_professores_nao_permanentes[area], bins=30, kde=True, color='skyblue', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

# Remove o subplot extra (o 6º)
fig.delaxes(axes[-1])
fig.delaxes(axes[-2])

plt.tight_layout()
plt.show()

# %% [markdown]
# Análise dos valores referente a quantidades:

# %%
quantidades = ['qtd_aprovado', 'qtd_desistencia',
       'qtd_reprovado_por_média_e_por_faltas', 'qtd_trancado',
       'qtd_aprovado_por_nota', 'qtd_reprovado', 'qtd_reprovado_por_faltas',
       'qtd_reprovado_por_nota_e_falta', 'qtd_reprovado_por_nota']

print("=== Médias puras ===\n")

for column in quantidades:
    media = df_professores_nao_permanentes[column].mean()
    print(f"{column:40s}: {media:.2f}")

print("\n==============================")

quantidades = ['porcentagem_aprovado_total', 'porcentagem_aprovado',
       'porcentagem_reprovado_total', 'porcentagem_reprovado_por_faltas_total',
       'porcentagem_trancado', 'porcentagem_desistencia_total']

print("=== Médias relativas ===\n")

for column in quantidades:
    media = df_professores_nao_permanentes[column].mean()
    print(f"{column:40s}: {media:.2f}")

print("\n==============================")
# Out:
# === Médias puras ===
#
# qtd_aprovado                            : 19.67
# qtd_desistencia                         : 0.73
# qtd_reprovado_por_média_e_por_faltas    : 1.10
# qtd_trancado                            : 0.88
# qtd_aprovado_por_nota                   : 3.35
# qtd_reprovado                           : 2.01
# qtd_reprovado_por_faltas                : 0.02
# qtd_reprovado_por_nota_e_falta          : 0.01
# qtd_reprovado_por_nota                  : 0.05
#
# ...
# === Médias relativas ===
#
# porcentagem_aprovado_total              : 88.70
# porcentagem_aprovado                    : 76.46
# porcentagem_reprovado_total             : 11.06
# porcentagem_reprovado_por_faltas_total  : 4.04
# porcentagem_trancado                    : 3.48
# porcentagem_desistencia_total           : 6.89
#
# ...

# %%
classes = ['sexo', 'formacao', 'categoria', 'classe_funcional',
       'lotacao']

print("=== Ocorrências de cada valor ===\n")

for column in classes:
    numOcorrencias = df_professores_nao_permanentes[column].value_counts()
    print(str(numOcorrencias) + "\n")

print("\n==============================")
# Out:
# === Ocorrências de cada valor ===
#
# sexo
# F    1099
# M    1039
# Name: count, dtype: int64
#
# formacao
# MESTRADO          997
# DOUTORADO         932
# ESPECIALIZAÇÃO    177
# GRADUAÇÃO          32
# Name: count, dtype: int64
#
# categoria
# PROFESSOR DO MAGISTERIO SUPERIOR - SUBSTITUTO    1616
# PROFESSOR DO MAGISTERIO SUPERIOR - TEMPORARIO     332
# PROFESSOR MAGISTERIO SUPERIOR - VISITANTE         168
# PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO            22
# Name: count, dtype: int64
#
# classe_funcional
# Auxiliar                                                                                                1948
# A                                                                                                        104
# Adjunto                                                                                                   58
# DI                                                                                                        22
# ...

# %% [markdown]
# ### Análise das notas em relação ao ano

# %%
df_notas = pd.DataFrame()
df_notas['atuacao_profissional_media'] = df['atuacao_profissional_media']
df_notas['postura_profissional_media'] = df['postura_profissional_media']
df_notas['autoavaliacao_aluno_media'] = df['autoavaliacao_aluno_media']
df_notas['media_final_geral'] = df['media_final_geral']
df_notas['ano'] = df['ano']

df_melt = pd.melt(
    df_notas,
    id_vars=['ano'],
    value_vars=[
        'atuacao_profissional_media',
        'postura_profissional_media',
        'autoavaliacao_aluno_media',
        'media_final_geral'
    ],
    var_name='variavel',
    value_name='valor'
)

anos = list(range(2013, 2023))  


# Agora plota
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_melt, x='ano', y='valor', hue='variavel')
plt.title('Evolução das Notas por Ano')
plt.xlabel('Ano')
plt.ylabel('Nota Média')
plt.legend(title='Variável')
plt.xticks(anos)
plt.tight_layout()
plt.show()

# %%
for metrica in ['atuacao_profissional_media','postura_profissional_media','autoavaliacao_aluno_media','media_final_geral']:
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df, y=metrica, x='formacao', hue='formacao')
    plt.title(f"{metrica} vs. Formação")
    plt.show()

# %%
df['formacao'].value_counts()
# Out:
# formacao
# DOUTORADO         102655
# MESTRADO           17643
# ESPECIALIZAÇÃO      5877
# GRADUAÇÃO             51
# PÓS-DOUTORADO         45
# DESCONHECIDA          23
# Name: count, dtype: int64

# %% [markdown]
# ### Análise por área do conhecimento

# %% [markdown]
# A coluna de "lotação" indica o setor/departamento etc. da Universidade à qual a turma pertence. Assim podemos dividir os dados com base na área de conhecimento abordada em cada turma.

# %% [markdown]
# #### Dividindo as áreas

# %%
# Categorias
exatas = [
    'ESCOLA DE CIÊNCIAS E TECNOLOGIA',
    'INSTITUTO DE QUÍMICA',
    'DEPARTAMENTO DE MATEMÁTICA',
    'DEPARTAMENTO DE FÍSICA TEÓRICA E EXPERIMENTAL',
    'DEPARTAMENTO DE GEOLOGIA',
    'INSTITUTO METROPOLE DIGITAL',
    'DEPARTAMENTO DE ENGENHARIA CIVIL E AMBIENTAL',
    'DEPARTAMENTO DE ENGENHARIA MECANICA',
    'DEPARTAMENTO DE ENGENHARIA QUIMICA',
    'DEPARTAMENTO DE ESTATISTICA',
    'DEPARTAMENTO DE INFORMÁTICA E MATEMÁTICA APLICADA',
    'DEPARTAMENTO DE ENGENHARIA DE COMPUTAÇÃO E AUTOMAÇÃO',
    'DEPARTAMENTO DE ENGENHARIA ELÉTRICA',
    'DEPARTAMENTO DE ENGENHARIA DE MATERIAIS',
    'DEPARTAMENTO DE ENGENHARIA DE COMUNICAÇÕES',
    'DEPARTAMENTO DE ENGENHARIA DE PETRÓLEO'
]

humanas = [
    'DEPARTAMENTO DE FUNDAMENTOS E POLÍTICAS DA EDUCAÇÃO',
    'DEPARTAMENTO DE PRÁTICAS EDUCACIONAIS E CURRÍCULO',
    'DEPARTAMENTO DE COMUNICAÇÃO SOCIAL',
    'DEPARTAMENTO DE CIÊNCIAS CONTÁBEIS - DCC',
    'DEPARTAMENTO DE DIREITO PRIVADO - DIPRI',
    'DEPARTAMENTO DE CIÊNCIAS ADMINISTRATIVAS - DEPAD',
    'DEPARTAMENTO DE ARTES',
    'DEPARTAMENTO DE PSICOLOGIA',
    'DEPARTAMENTO DE GEOGRAFIA/CCHLA',
    'FACULDADE DE ENGENHARIA, LETRAS E CIÊNCIAS SOCIAIS DO SERIDÓ - FELCS',
    'DEPARTAMENTO DE ADMINISTRAÇÃO PÚBLICA E GESTÃO SOCIAL',
    'DEPARTAMENTO DE LETRAS'
]

biologicas = [
    'ESCOLA MULTICAMPI DE CIÊNCIAS MÉDICAS DO RIO GRANDE DO NORTE',
    'DEPARTAMENTO DE MEDICINA INTEGRADA',
    'DEPARTAMENTO DE MEDICINA CLÍNICA',
    'DEPARTAMENTO DE ODONTOLOGIA',
    'FACULDADE DE CIÊNCIAS DA SAÚDE DO TRAIRI - FACISA',
    'DEPARTAMENTO DE FARMÁCIA',
    'DEPARTAMENTO DE ANÁLISES CLÍNICAS E TOXICOLÓGICAS',
    'DEPARTAMENTO DE NUTRIÇÃO',
    'DEPARTAMENTO DE PATOLOGIA',
    'DEPARTAMENTO DE PEDIATRIA',
    'DEPARTAMENTO DE MORFOLOGIA',
    'DEPARTAMENTO DE ENFERMAGEM',
    'DEPARTAMENTO DE TOCO-GINECOLOGIA',
    'DEPARTAMENTO DE FISIOTERAPIA',
    'DEPARTAMENTO DE MICROBIOLOGIA E PARASITOLOGIA',
    'DEPARTAMENTO DE CIRURGIA',
    'DEPARTAMENTO DE FISIOLOGIA E COMPORTAMENTO',
    'DEPARTAMENTO DE BIOFÍSICA E FARMACOLOGIA',
    'ESCOLA DE SAÚDE',
    'DEPARTAMENTO DE INFECTOLOGIA',
    'DEPARTAMENTO DE BIOLOGIA CELULAR E GENÉTICA',
    'DEPARTAMENTO DE BOTÂNICA E ZOOLOGIA',
    'DEPARTAMENTO DE BIOQUÍMICA'
]

df_exatas = df[df['lotacao'].isin(exatas)].copy()
df_humanas = df[df['lotacao'].isin(humanas)].copy()
df_biologicas = df[df['lotacao'].isin(biologicas)].copy()

# %% [markdown]
# É interessante vermos as quantidade de registros em cada dataset, visto que isso pode influenciar os valores apresentados em gráficos e em médias.

# %%
print('Linhas em \"Exatas\": ' + str(len(df_exatas)))
print('Linhas em \"Humanas\": ' + str(len(df_humanas)))
print('Linhas em \"Biológicas\": ' + str(len(df_biologicas)))
# Out:
# Linhas em "Exatas": 20018
# Linhas em "Humanas": 14412
# Linhas em "Biológicas": 62084

# %% [markdown]
# #### Exatas

# %%
areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df_exatas[area], bins=30, kde=True, color='skyblue', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')


plt.tight_layout()
plt.show()

# %%
df_notas_exatas = pd.DataFrame()
df_notas_exatas['atuacao_profissional_media'] = df_exatas['atuacao_profissional_media']
df_notas_exatas['postura_profissional_media'] = df_exatas['postura_profissional_media']
df_notas_exatas['autoavaliacao_aluno_media'] = df_exatas['autoavaliacao_aluno_media']
df_notas_exatas['media_final_geral'] = df_exatas['media_final_geral']
df_notas_exatas['ano'] = df_exatas['ano']

df_melt = pd.melt(
    df_notas_exatas,
    id_vars=['ano'],
    value_vars=[
        'atuacao_profissional_media',
        'postura_profissional_media',
        'autoavaliacao_aluno_media',
        'media_final_geral'
    ],
    var_name='variavel',
    value_name='valor'
)

anos = list(range(2013, 2023))  


# Agora plota
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_melt, x='ano', y='valor', hue='variavel')
plt.title('Evolução das Notas por Ano: Exatas')
plt.xlabel('Ano')
plt.ylabel('Nota Média')
plt.legend(title='Variável')
plt.xticks(anos)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Humanas

# %%
areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df_humanas[area], bins=30, kde=True, color='red', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

plt.tight_layout()
plt.show()

# %%
df_notas_humanas = pd.DataFrame()
df_notas_humanas['atuacao_profissional_media'] = df_humanas['atuacao_profissional_media']
df_notas_humanas['postura_profissional_media'] = df_humanas['postura_profissional_media']
df_notas_humanas['autoavaliacao_aluno_media'] = df_humanas['autoavaliacao_aluno_media']
df_notas_humanas['media_final_geral'] = df_humanas['media_final_geral']
df_notas_humanas['ano'] = df_humanas['ano']

df_melt = pd.melt(
    df_notas_humanas,
    id_vars=['ano'],
    value_vars=[
        'atuacao_profissional_media',
        'postura_profissional_media',
        'autoavaliacao_aluno_media',
        'media_final_geral'
    ],
    var_name='variavel',
    value_name='valor'
)

anos = list(range(2013, 2023))  


# Agora plota
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_melt, x='ano', y='valor', hue='variavel')
plt.title('Evolução das Notas por Ano: Humanas')
plt.xlabel('Ano')
plt.ylabel('Nota Média')
plt.legend(title='Variável')
plt.xticks(anos)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Biológicas

# %%
areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao']
fig, axes = plt.subplots(1, 4, figsize=(24, 5))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df_biologicas[area], bins=30, kde=True, color='green', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

plt.tight_layout()
plt.show()

# %%
df_notas_biologicas = pd.DataFrame()
df_notas_biologicas['atuacao_profissional_media'] = df_biologicas['atuacao_profissional_media']
df_notas_biologicas['postura_profissional_media'] = df_biologicas['postura_profissional_media']
df_notas_biologicas['autoavaliacao_aluno_media'] = df_biologicas['autoavaliacao_aluno_media']
df_notas_biologicas['media_final_geral'] = df_biologicas['media_final_geral']
df_notas_biologicas['ano'] = df_biologicas['ano']

df_melt = pd.melt(
    df_notas_biologicas,
    id_vars=['ano'],
    value_vars=[
        'atuacao_profissional_media',
        'postura_profissional_media',
        'autoavaliacao_aluno_media',
        'media_final_geral'
    ],
    var_name='variavel',
    value_name='valor'
)

anos = list(range(2013, 2023))  


# Agora plota
plt.figure(figsize=(8, 5))
sns.lineplot(data=df_melt, x='ano', y='valor', hue='variavel')
plt.title('Evolução das Notas por Ano: Biológicas')
plt.xlabel('Ano')
plt.ylabel('Nota Média')
plt.legend(title='Variável')
plt.xticks(anos)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### IMD e DIMAp

# %%
IMD_e_DIMAp = [
    'INSTITUTO METROPOLE DIGITAL',
    'DEPARTAMENTO DE INFORMÁTICA E MATEMÁTICA APLICADA'
]

df_IMD_e_DIMAp = df[df['lotacao'].isin(IMD_e_DIMAp)].copy()

areas = ['postura_profissional_media', 'atuacao_profissional_media', 'autoavaliacao_aluno_media', 'ano_admissao']
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
axes = axes.flatten()

for i, area in enumerate(areas):
    sns.histplot(df_IMD_e_DIMAp[area], bins=30, kde=True, color='skyblue', ax=axes[i])
    axes[i].set_title(f'Distribuição dos valores: {area}')
    axes[i].set_xlabel('Valores')
    axes[i].set_ylabel('Frequência')

# Remove o subplot extra (o 6º)
fig.delaxes(axes[-1])
fig.delaxes(axes[-2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Não Sei o que é isso (- Marina)
# Acho que estavam querendo olhar os dados dos professores sem criptografia...

# %%
fd = pd.read_csv("../limpezaSegundafase/CSVs/Finais/docentes_e_avaliação.csv", sep = ";")
fd = fd[fd["formacao"] == "GRADUAÇÃO"]
fd
# Out:
#                                       nome sexo   formacao  \
# 2018            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2019            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2020            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2021            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2022            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2023            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2024            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 2025            RONEDILK CAVALCANTE DANTAS    M  GRADUAÇÃO
# 123804   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123805   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123806   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123807   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123808   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123809   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# 123810   ADEMARCIA LOPES DE OLIVEIRA COSTA    F  GRADUAÇÃO
# ...
